# %% [markdown]
# 1. The population of a town is 198568. Out of them 45312 are men and 35678 are women. Find the number of children in the town.

# %%
population = 198568
men = 45312
women = 35678
print("children = ",population- men- women)
# Out:
# children =  117578

# %% [markdown]
# 2. A shopkeeper has 2425 boxes of 24 pencils each. How many pencils do all the boxes have in all?

# %%
box = 2425
pencil = 24 
print("total = ",box*pencil)
# Out:
# total =  58200

# %% [markdown]
# 3. Linda bought a coat for $2265 and a saree for $2150. She gave $5000 to the shopkeeper. How much money did the shopkeeper return to her?

# %%
coat = 2265
saree = 2150
print("balance ",5000 - coat - saree)
# Out:
# balance  585

# %% [markdown]
# 4 The cost of 21 TV sets is $95844. Find the cost of one TV set.

# %%
total_tv = 21 
print("cost of one tv = " ,95844/total_tv)
# Out:
# cost of one tv =  4564.0

# %% [markdown]
# #Type of variable
# int
# bool
# string
# float

# %% [markdown]
# #single line comment
# """ this is multi line comment """

# %%
a = 4
type(a)
# Out:
# int

# %%
is_saturday = True
type(is_saturday)
# Out:
# bool

# %%
name = "meghana"
type(name)
# Out:
# str

# %%
names = ["meghana" , "preetham"]
type(names)
# Out:
# list

# %%
numbers =(1,2,3,4,5)
type(numbers)
# Out:
# tuple

# %%
app = 3.4
type(app)
# Out:
# float

# %%
map = {"name" : "meghana" , "age" : 21}
type(map)
# Out:
# dict

# %%
nothing = None
type(nothing)
# Out:
# NoneType

# %% [markdown]
# To use a double quote within a string written with double quotes, escape the inner quotes by prefixing them with the \ character.

# %%
sentence = "python is a \"programming language \" "
print(sentence)
# Out:
# python is a "programming language "

# %%
yet_another_pun = '''Son: "Dad, can you tell me what a solar eclipse is?" 
Dad: "No sun."'''

# %%
print(yet_another_pun)
# Out:
# Son: "Dad, can you tell me what a solar eclipse is?"
# Dad: "No sun."

# %%
name = "meghana"

print(name + " hi")
# Out:
# meghana hi

# %%
name = "meghana"
name=name.lower()
print(name)
name=name.upper()
print(name)
name=name.capitalize()
print(name)
name=name.replace("m","M")
print(name)
# Out:
# meghana
# MEGHANA
# Meghana
# Meghana

# %%
name="m,e,g,h,a,n,a".split(",")
print(name)
# Out:
# ['m', 'e', 'g', 'h', 'a', 'n', 'a']

# %%
sentence = "    python is a programming language....    so  i love it      "
sentence = sentence.strip()
print(sentence)
# Out:
# python is a programming language....    so  i love it

# %% [markdown]
# .format method combines values of other data types e.g integers , float , boolean , lists with string

# %%
cost = 1.23
profit = 0.23
bags = 100
profit =  cost * profit * bags
out_messg = " cost = {} profit = {} bags = {} total profit is {}"

out_messg = out_messg.format(cost,profit*100,bags,profit)
print(out_messg)
# Out:
#  cost = 1.23 profit = 2829.0 bags = 100 total profit is 28.29

# %%
name = ["python","java","c++"]
print(str(name))
# Out:
# ['python', 'java', 'c++']

# %%
fruits = ["apple","banana","grapes","mango"]
print(fruits)
type(fruits)
# Out:
# ['apple', 'banana', 'grapes', 'mango']
# list

# %%
a_list = [1,"happy",fruits,2>3,6.8,None]
print(a_list)
print("length = ",len(a_list))
print(a_list[1:])
print(a_list[:3])
print(a_list[1:10])
print(a_list[-2:-4])
print(a_list[-4:-2])
# Out:
# [1, 'happy', ['apple', 'banana', 'grapes', 'mango'], False, 6.8, None]
# length =  6
# ['happy', ['apple', 'banana', 'grapes', 'mango'], False, 6.8, None]
# [1, 'happy', ['apple', 'banana', 'grapes', 'mango']]
# ['happy', ['apple', 'banana', 'grapes', 'mango'], False, 6.8, None]
# []
# [['apple', 'banana', 'grapes', 'mango'], False]

# %%
# ?tuple.index
# Out:
# Signature: tuple.index(self, value, start=0, stop=9223372036854775807, /)
# Docstring:
# Return first index of value.
#
# Raises ValueError if the value is not present.
# Type:      method_descriptor

# %%
help(tuple.count)
help(tuple.index)
# Out:
# Help on method descriptor count:
#
# count(self, value, /) unbound builtins.tuple method
#     Return number of occurrences of value.
#
# Help on method descriptor index:
#
# index(self, value, start=0, stop=9223372036854775807, /) unbound builtins.tuple method
#     Return first index of value.
#
#     Raises ValueError if the value is not present.
